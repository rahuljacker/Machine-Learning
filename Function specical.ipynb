# %%
import pandas as pd

# %%
rahul=[1,2,3,4,5,6,7,8,]

# %%
rahul
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
 pwd
# Out:
# 'C:\\Users\\Rahul'

# %%
rahul="ndim"

# %%
import numpy as np

# %%
gh=np.resize(rahul,(3,5))

# %%
gh
# Out:
# array([['ndim', 'ndim', 'ndim', 'ndim', 'ndim'],
#        ['ndim', 'ndim', 'ndim', 'ndim', 'ndim'],
#        ['ndim', 'ndim', 'ndim', 'ndim', 'ndim']], dtype='<U4')

# %%
print("value of rahul\n{}\n value of rahul\n {}".format(rahul,rahul))
# Out:
# value of rahul
# ndim
#  value of rahul
#  ndim

# %%
rahul=np.eye(3)

# %%
rahul
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
rahul.size
# Out:
# 9

# %%
rahul.shape
# Out:
# (3, 3)

# %%
type(rahul)
# Out:
# numpy.ndarray

# %%
import pandas as pd

# %%
tata=pd.read_csv(r"H:\machine learning\New Datasets\DataSets-master\DataSets-master\Titanic_Data.csv")

# %%
tata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
tata.loc[:,"Name":"Age"]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# 5                                     Moran, Mr. James    male   NaN
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 7                       Palsson, Master. Gosta Leonard    male   2.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 12                      Saundercock, Mr. William Henry    male  20.0
# ...

# %%
tata.loc[1:10,["Name","Parch","age",]]
# Out:
# C:\Users\Rahul\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                  Name  Parch  age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0  NaN
# 2                              Heikkinen, Miss. Laina      0  NaN
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  NaN
# 4                            Allen, Mr. William Henry      0  NaN
# 5                                    Moran, Mr. James      0  NaN
# 6                             McCarthy, Mr. Timothy J      0  NaN
# 7                      Palsson, Master. Gosta Leonard      1  NaN
# ...

# %%
tata.loc[:4,["Name","Parch","Age"]]
# Out:
#                                                 Name  Parch   Age
# 0                            Braund, Mr. Owen Harris      0  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0  38.0
# 2                             Heikkinen, Miss. Laina      0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  35.0
# 4                           Allen, Mr. William Henry      0  35.0

# %%
tata.loc[3:,["Name","Age","parch"]]
# Out:
# C:\Users\Rahul\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                   Name   Age  parch
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    NaN
# 4                             Allen, Mr. William Henry  35.0    NaN
# 5                                     Moran, Mr. James   NaN    NaN
# 6                              McCarthy, Mr. Timothy J  54.0    NaN
# 7                       Palsson, Master. Gosta Leonard   2.0    NaN
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0    NaN
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0    NaN
# ...

# %%
tata.loc[3:4:6,["Name","Age","Parch"]]
# Out:
#                                            Name   Age  Parch
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0

# %%
tata.loc[:,["Name","Age","Parch"]]
# Out:
#                                                   Name   Age  Parch
# 0                              Braund, Mr. Owen Harris  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0
# 2                               Heikkinen, Miss. Laina  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0
# 4                             Allen, Mr. William Henry  35.0      0
# 5                                     Moran, Mr. James   NaN      0
# 6                              McCarthy, Mr. Timothy J  54.0      0
# 7                       Palsson, Master. Gosta Leonard   2.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      0
# 10                     Sandstrom, Miss. Marguerite Rut   4.0      1
# 11                            Bonnell, Miss. Elizabeth  58.0      0
# 12                      Saundercock, Mr. William Henry  20.0      0
# ...

# %%
tata.loc[5:,["Age",]]
# Out:
#       Age
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# 10    4.0
# 11   58.0
# 12   20.0
# 13   39.0
# 14   14.0
# 15   55.0
# 16    2.0
# 17    NaN
# 18   31.0
# 19    NaN
# 20   35.0
# 21   34.0
# 22   15.0
# 23   28.0
# 24    8.0
# 25   38.0
# 26    NaN
# 27   19.0
# 28    NaN
# 29    NaN
# 30   40.0
# 31    NaN
# 32    NaN
# 33   66.0
# 34   28.0
# ..    ...
# 861  21.0
# 862  48.0
# 863   NaN
# 864  24.0
# 865  42.0
# 866  27.0
# 867  31.0
# 868   NaN
# 869   4.0
# 870  26.0
# 871  47.0
# 872  33.0
# 873  47.0
# 874  28.0
# 875  15.0
# 876  20.0
# 877  19.0
# 878   NaN
# 879  56.0
# 880  25.0
# 881  33.0
# 882  22.0
# 883  28.0
# 884  25.0
# 885  39.0
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [886 rows x 1 columns]

# %%
import pandas as pd

# %%
work=pd.read_csv(r"H:\machine learning\New Datasets\DataSets-master\DataSets-master\employees.csv")

# %%
work
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
work.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
name=work[work["Senior Management"]==False]

# %%
name
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2          Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 5         Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 13          Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 15       Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 16        Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 17         Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18         Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19         Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 21       Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 24          John    Male    7/1/1992        10:08 PM   97950   13.873
# 27         Scott     NaN   7/11/1991         6:58 PM  122367    5.218
# 31         Joyce     NaN   2/20/2005         2:40 PM   88657   12.752
# ...

# %%
name.head(4)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 5      Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# 13       Gary    Male  1/27/2008        11:40 PM  109831    5.831
# 15    Lillian  Female   6/5/2016         6:09 AM   59414    1.256
#
#    Senior Management     Team
# 2              False  Finance
# 5              False    Legal
# 13             False    Sales
# 15             False  Product

# %%
productteam =name[name["Team"]=="Product"]

# %%
productteam
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 17       Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 19       Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 31       Joyce     NaN   2/20/2005         2:40 PM   88657   12.752
# 72       Bobby    Male    5/7/2007        10:01 AM   54043    3.833
# 79      Bonnie  Female  11/13/1988         3:30 PM  115814    4.990
# 115     Pamela  Female    7/1/1982         6:51 AM   54585    4.166
# 121   Kathleen     NaN    5/9/2016         8:55 AM  119735   18.740
# 131    Rebecca  Female   7/10/1992        12:23 AM   94231   17.517
# 146   Patricia  Female  11/25/1992         2:24 AM   95322    4.150
# 176     Victor    Male    1/8/2003         1:02 PM  124486   10.166
# 178       Jane  Female    9/3/1997         2:01 AM  144474   17.648
# 231      Diane  Female   4/18/1993         3:22 AM   64084   17.018
# ...

# %%
productteamfemale=productteam[productteam["Gender"]=='Female']

# %%
productteamfemale
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 19       Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 79      Bonnie  Female  11/13/1988         3:30 PM  115814    4.990
# 115     Pamela  Female    7/1/1982         6:51 AM   54585    4.166
# 131    Rebecca  Female   7/10/1992        12:23 AM   94231   17.517
# 146   Patricia  Female  11/25/1992         2:24 AM   95322    4.150
# 178       Jane  Female    9/3/1997         2:01 AM  144474   17.648
# 231      Diane  Female   4/18/1993         3:22 AM   64084   17.018
# 236      Laura  Female    4/2/2006         1:57 PM   42087    2.624
# 261      Marie  Female    8/6/1995         1:58 PM  100308   13.677
# 316      Marie  Female   10/3/2013         8:05 PM  123711   10.966
# 342      Marie  Female  10/20/2011        10:09 PM   62666   10.247
# 369       Mary  Female  10/18/2009         6:32 PM   87721   12.484
# ...

# %%
productteamincome=productteamfemale[productteamfemale["Salary"]>90000]

# %%
productteamincome
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 79      Bonnie  Female  11/13/1988         3:30 PM  115814    4.990
# 131    Rebecca  Female   7/10/1992        12:23 AM   94231   17.517
# 146   Patricia  Female  11/25/1992         2:24 AM   95322    4.150
# 178       Jane  Female    9/3/1997         2:01 AM  144474   17.648
# 261      Marie  Female    8/6/1995         1:58 PM  100308   13.677
# 316      Marie  Female   10/3/2013         8:05 PM  123711   10.966
# 598    Frances  Female   7/21/2001         2:34 AM   91996   11.506
# 828    Cynthia  Female   7/12/2006         8:55 AM  149684    7.864
# 842     Sandra  Female    2/7/1998        12:39 PM  132327   19.264
# 868  Katherine  Female   8/18/2013         3:58 PM   97443   13.657
# 977      Sarah  Female   12/4/1995         9:16 AM  124566    5.949
#
#     Senior Management     Team
# 79              False  Product
# 131             False  Product
# 146             False  Product
# ...

# %%
namelist=productteamfemale[productteamfemale["First Name"]=="Jane"]

# %%
namelist
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 178       Jane  Female   9/3/1997         2:01 AM  144474   17.648
#
#     Senior Management     Team
# 178             False  Product

# %%
namelistd=productteamincome[productteamincome["First Name"]=="Sandra"]

# %%
namelistd
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 842     Sandra  Female   2/7/1998        12:39 PM  132327   19.264
#
#     Senior Management     Team
# 842             False  Product

# %%
import pandas as pd

# %%
multi=pd.read_csv(r"H:\machine learning\New Datasets\DataSets-master\DataSets-master\Advertising.csv")

# %%
multi
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
multi.head(5)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
multi.shape
# Out:
# (200, 5)

# %%
x_input=multi.iloc[:,1:4]

# %%
x_input.head(5)
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y_output=multi.iloc[:,4]

# %%
multi.keys()
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
y_output
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
#        ...
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
x_input.shape
#y_output.shape
# Out:
# (200, 3)

# %%
#or we can use (200,3) to reshape 
X_input=x_input.values.reshape(200,3)

# %%
#or we can use (200,1) to reshape
Y_output=y_output.values.reshape(200,1)

# %%
Y_output
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %%
X_train=X_input[:140]

# %%
X_test=X_input[140:]

# %%
Y_train=Y_output[:140]

# %%
Y_test=Y_output[140:]

# %%
from sklearn.linear_model import LinearRegression

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(X_train,Y_train)

# %%
yp=learner.predict(X_test)
yplist=list(yp)

# %%
ya=Y_test

# %%
multi.head(5)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
xlist=list(X_test)
yalist=list(Y_test)

# %%
newtable=pd.DataFrame({"ya":yalist,"yp":yplist})

# %%
newtable
# Out:
#         ya                    yp
# 0   [10.9]   [9.514354402169253]
# 1   [19.2]   [18.29202876551769]
# 2   [20.1]  [19.270940642386797]
# 3   [10.4]    [8.88723581838406]
# 4   [11.4]  [10.113617055260615]
# 5   [10.3]   [9.960419720902921]
# 6   [13.2]  [15.627067876574085]
# 7   [25.4]  [23.158701304668185]
# 8   [10.9]  [12.038450307585519]
# 9   [10.1]   [9.722124713181572]
# 10  [16.1]  [18.638094550760975]
# 11  [11.6]  [10.100998672157097]
# 12  [16.6]  [16.485896155663326]
# 13  [19.0]   [18.12468608681111]
# 14  [15.6]  [15.643642664262023]
# 15   [3.2]  [5.3052327502539605]
# 16  [15.3]  [15.127442314978547]
# 17  [10.1]  [10.253587248475565]
# 18   [7.3]  [10.090062519977868]
# 19  [12.9]  [12.443627914665923]
# 20  [14.4]   [14.32103089965689]
# 21  [13.3]  [13.361690795894438]
# 22  [14.9]  [15.084433307031002]
# 23  [18.0]  [17.327694332838675]
# 24  [11.9]   [11.18435748639172]
# 25  [11.9]   [14.43410809882653]
# 26   [8.0]  [10.578473771006653]
# ...

# %%
#error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error=np.sqrt(mean_squared_error(ya,yp))

# %%
error
# Out:
# 1.5993642253910214

# %%
m= learner.coef_

# %%
m
# Out:
# array([[ 0.04704868,  0.17968299, -0.00300557]])

# %%
c=learner.intercept_

# %%
c
# Out:
# array([3.04514221])

# %%
m1=m[0,0]

# %%
m1
# Out:
# 0.047048680822289274

# %%
m3=m[0,2]

# %%
m3
# Out:
# -0.003005565156806662
